# %%
import sqlite3

# %%
import pandas as pd

# %%
df = pd.read_csv('nutrition.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
data = df[['name', 'calories', 'total_fat', 'protein', 'carbohydrate']]

# %%
data = pd.DataFrame()
data['name'] = df['name'].str.lower()
data['calories'] = df['calories'].astype(int)
data['fats'] = df['total_fat'].str.replace(r'[^\d.]', '', regex=True).astype(float)
data['proteins'] = df['protein'].str.replace(r'[^\d.]', '', regex=True).astype(float)
data['carbohydrates'] = df['carbohydrate'].str.replace(r'[^\d.]', '', regex=True).astype(float)

# %%
data.head()
# Out:
#               name  calories  fats  proteins  carbohydrates
# 0       cornstarch       381   0.1      0.26          91.27
# 1     nuts, pecans       691  72.0      9.17          13.86
# 2    eggplant, raw        25   0.2      0.98           5.88
# 3   teff, uncooked       367   2.4     13.30          73.13
# 4  sherbet, orange       144   2.0      1.10          30.40

# %%
 data['name']=data['name'].str.lower()

# %%
dataset = data.set_index('name')

# %%
import pandas as pd
import sqlalchemy as sa

db_url = "sqlite:///./meal_mentor.db"
engine = sa.create_engine(db_url)
inspector = sa.inspect(engine)

# %%
tables = inspector.get_table_names()
tables
# Out:
# ['meal_logs', 'users']

# %%
meal_logs = tables[0]  
users = tables[1]  

meals_columns = inspector.get_columns(meal_logs)
users_columns = inspector.get_columns(users)
print('MEALS')
for col in meals_columns:
    print(col['name'], col['type'])
print('USERS')
for col in users_columns:
    print(col['name'], col['type'])
# Out:
# MEALS
# id INTEGER
# user_id INTEGER
# telegram_file_id VARCHAR(255)
# ingredients_json TEXT
# nutrition_json TEXT
# created_at DATETIME
# USERS
# id INTEGER
# telegram_id INTEGER
# username VARCHAR(255)
# created_at DATETIME

# %%
print("pandas:", pd.__version__)
print("sqlalchemy:", sa.__version__)
# Out:
# pandas: 2.2.0
# sqlalchemy: 1.4.54

# %%
conn = sqlite3.connect("meal_mentor.db")
df_users = pd.read_sql_query("SELECT * FROM users LIMIT 10", conn)
df_users
# Out:
#    id  telegram_id  username                  created_at
# 0   1    316257868  KritBong  2026-03-11 15:48:56.116994

# %%
df_meals = pd.read_sql_query("SELECT * FROM meal_logs LIMIT 10", conn)

df_meals
# Out:
#    id  user_id                                   telegram_file_id  \
# 0   1        1  AgACAgIAAxkBAAMGabGM05vt9goI_9IYbCv8m1ebkJMAAr...
# 1   2        1  AgACAgIAAxkBAAMDabGK9i7Ze7etUnwqKCa-dbQ83xYAAq...
# 2   3        1  AgACAgIAAxkBAAMTabGP8qlrIc7xWvmo_uh1bpTfs7MAAt...
# 3   4        1  AgACAgIAAxkBAAMaabpe-MVbZ6hlO2jL2aq6gOOoZ4cAAp...
#
#                                     ingredients_json  \
# 0          {"eggs": 100, "beans": 150, "cheese": 50}
# 1  {"lettuce": 50, "tomato": 30, "onion": 20, "pa...
# 2                                                 {}
# 3  {"arugula": 50, "cherry tomatoes": 60, "feta c...
#
#                                       nutrition_json  \
# 0  {"calories": 220, "proteins": 12, "fats": 14, ...
# 1  {"calories": 655, "proteins": 42, "fats": 5, "...
# 2                                                 {}
# 3  {"calories": 134, "proteins": 4, "fats": 6, "c...
#
#                    created_at
# 0  2026-03-11 15:48:56.119273
# ...
