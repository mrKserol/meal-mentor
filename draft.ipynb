# %%
import pandas as pd

# %%
df = pd.read_csv('nutrition.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 77 columns]

# %%
data = df[['name', 'calories', 'total_fat', 'protein', 'carbohydrate']]

# %%
data = pd.DataFrame()
data['name'] = df['name'].str.lower()
data['calories'] = df['calories'].astype(int)
data['fats'] = df['total_fat'].str.replace(r'[^\d.]', '', regex=True).astype(float)
data['proteins'] = df['protein'].str.replace(r'[^\d.]', '', regex=True).astype(float)
data['carbohydrates'] = df['carbohydrate'].str.replace(r'[^\d.]', '', regex=True).astype(float)

# %%
data.head()
# Out:
#               name  calories  fats  proteins  carbohydrates
# 0       cornstarch       381   0.1      0.26          91.27
# 1     nuts, pecans       691  72.0      9.17          13.86
# 2    eggplant, raw        25   0.2      0.98           5.88
# 3   teff, uncooked       367   2.4     13.30          73.13
# 4  sherbet, orange       144   2.0      1.10          30.40

# %%
 data['name']=data['name'].str.lower()
# Out:
# /var/folders/kq/dmy4ffs56xj_0h72qcbpyf400000gn/T/ipykernel_69770/966699872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['name']=data['name'].str.lower()

# %%
dataset = data.set_index('name')

# %%
dataset = dataset.str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kq/dmy4ffs56xj_0h72qcbpyf400000gn/T/ipykernel_82181/3355802681.py in ?()
# ----> 1 dataset = dataset.str.lower()
#
# /opt/anaconda3/envs/mlops-py311/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
dataset.to_dict('index')
# Out:
# {'Cornstarch': {'calories': 381,
#   'fats': 0.1,
#   'proteins': 0.26,
#   'carbohydrates': 91.27},
#  'Nuts, pecans': {'calories': 691,
#   'fats': 72.0,
#   'proteins': 9.17,
#   'carbohydrates': 13.86},
#  'Eggplant, raw': {'calories': 25,
#   'fats': 0.2,
#   'proteins': 0.98,
#   'carbohydrates': 5.88},
#  'Teff, uncooked': {'calories': 367,
#   'fats': 2.4,
#   'proteins': 13.3,
#   'carbohydrates': 73.13},
#  'Sherbet, orange': {'calories': 144,
#   'fats': 2.0,
#   'proteins': 1.1,
#   'carbohydrates': 30.4},
#  'Cauliflower, raw': {'calories': 25,
#   'fats': 0.3,
#   'proteins': 1.92,
#   'carbohydrates': 4.97},
#  'Taro leaves, raw': {'calories': 42,
#   'fats': 0.7,
#   'proteins': 4.98,
#   'carbohydrates': 6.7},
#  'Lamb, raw, ground': {'calories': 282,
#   'fats': 23.0,
#   'proteins': 16.56,
#   'carbohydrates': 0.0},
#  'Cheese, camembert': {'calories': 300,
#   'fats': 24.0,
#   'proteins': 19.8,
#   'carbohydrates': 0.46},
#  'Vegetarian fillets': {'calories': 290,
#   'fats': 18.0,
#   'proteins': 23.0,
#   'carbohydrates': 9.0},
#  'PACE, Picante Sauce': {'calories': 25,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 6.25},
#  'Goji berries, dried': {'calories': 349,
#   'fats': 0.4,
#   'proteins': 14.26,
#   'carbohydrates': 77.06},
#  'Mango nectar, canned': {'calories': 51,
#   'fats': 0.1,
#   'proteins': 0.11,
#   'carbohydrates': 13.12},
#  'Crackers, rusk toast': {'calories': 407,
#   'fats': 7.2,
#   'proteins': 13.5,
#   'carbohydrates': 72.3},
#  'Chicken, boiled, feet': {'calories': 215,
#   'fats': 15.0,
#   'proteins': 19.4,
#   'carbohydrates': 0.2},
#  'Quail, raw, meat only': {'calories': 134,
#   'fats': 4.5,
#   'proteins': 21.76,
#   'carbohydrates': 0.0},
#  'Pie, lemon, fried pies': {'calories': 316,
#   'fats': 16.0,
#   'proteins': 3.0,
#   'carbohydrates': 42.6},
#  'Peppers, raw, jalapeno': {'calories': 29,
#   'fats': 0.4,
#   'proteins': 0.91,
#   'carbohydrates': 6.5},
#  'Winged bean tuber, raw': {'calories': 148,
#   'fats': 0.9,
#   'proteins': 11.6,
#   'carbohydrates': 28.1},
#  'Salami, turkey, cooked': {'calories': 172,
#   'fats': 9.2,
#   'proteins': 19.2,
#   'carbohydrates': 1.55},
#  'Grapes, raw, muscadine': {'calories': 57,
#   'fats': 0.5,
#   'proteins': 0.81,
#   'carbohydrates': 13.93},
#  'Nuts, raw, ginkgo nuts': {'calories': 182,
#   'fats': 1.7,
#   'proteins': 4.32,
#   'carbohydrates': 37.6},
#  'Spices, ground, savory': {'calories': 272,
#   'fats': 5.9,
#   'proteins': 6.73,
#   'carbohydrates': 68.73},
#  'Candies, sesame crunch': {'calories': 516,
#   'fats': 33.0,
#   'proteins': 11.6,
#   'carbohydrates': 50.3},
#  'Cheese, low fat, cream': {'calories': 201,
#   'fats': 15.0,
#   'proteins': 7.85,
#   'carbohydrates': 8.13},
#  'PACE, Green Taco Sauce': {'calories': 25,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 6.25},
#  'Syrup, Canadian, maple': {'calories': 270,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 67.38},
#  'Ostrich, raw, top loin': {'calories': 119,
#   'fats': 3.0,
#   'proteins': 21.67,
#   'carbohydrates': 0.0},
#  'Chewing gum, sugarless': {'calories': 268,
#   'fats': 0.4,
#   'proteins': 0.0,
#   'carbohydrates': 94.8},
#  'Nuts, dried, pine nuts': {'calories': 673,
#   'fats': 68.0,
#   'proteins': 13.69,
#   'carbohydrates': 13.08},
#  'Pasta, unenriched, dry': {'calories': 371,
#   'fats': 1.5,
#   'proteins': 13.04,
#   'carbohydrates': 74.67},
#  "McDONALD'S, Side Salad": {'calories': 20,
#   'fats': 0.2,
#   'proteins': 1.03,
#   'carbohydrates': 4.3},
#  'Cookies, Marie biscuit': {'calories': 406,
#   'fats': 11.0,
#   'proteins': 7.05,
#   'carbohydrates': 70.54},
#  'Broccoli, raw, chinese': {'calories': 30,
#   'fats': 0.8,
#   'proteins': 1.2,
#   'carbohydrates': 4.67},
#  "McDONALD'S, Hash Brown": {'calories': 271,
#   'fats': 16.0,
#   'proteins': 2.48,
#   'carbohydrates': 28.56},
#  'Agave, raw (Southwest)': {'calories': 68,
#   'fats': 0.2,
#   'proteins': 0.52,
#   'carbohydrates': 16.23},
#  'Emu, raw, outside drum': {'calories': 103,
#   'fats': 0.5,
#   'proteins': 23.08,
#   'carbohydrates': 0.0},
#  'Nuts, dried, beechnuts': {'calories': 576,
#   'fats': 50.0,
#   'proteins': 6.2,
#   'carbohydrates': 33.5},
#  'Currants, dried, zante': {'calories': 283,
#   'fats': 0.3,
#   'proteins': 4.08,
#   'carbohydrates': 74.08},
#  'Lentils, raw, sprouted': {'calories': 106,
#   'fats': 0.6,
#   'proteins': 8.96,
#   'carbohydrates': 22.14},
#  'Gravy, mix, dry, onion': {'calories': 322,
#   'fats': 3.0,
#   'proteins': 9.0,
#   'carbohydrates': 67.64},
#  'Pie, fruit, fried pies': {'calories': 316,
#   'fats': 16.0,
#   'proteins': 3.0,
#   'carbohydrates': 42.6},
#  'Snacks, cakes, popcorn': {'calories': 384,
#   'fats': 3.1,
#   'proteins': 9.7,
#   'carbohydrates': 80.1},
#  'Snack, Mixed Berry Bar': {'calories': 383,
#   'fats': 11.0,
#   'proteins': 13.16,
#   'carbohydrates': 58.84},
#  'Fish, raw, sheepshead': {'calories': 108,
#   'fats': 2.4,
#   'proteins': 20.21,
#   'carbohydrates': 0.0},
#  'Babyfood, pear, juice': {'calories': 47,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 11.86},
#  'Brussels sprouts, raw': {'calories': 43,
#   'fats': 0.3,
#   'proteins': 3.38,
#   'carbohydrates': 8.95},
#  'Broccoli raab, cooked': {'calories': 33,
#   'fats': 0.5,
#   'proteins': 3.83,
#   'carbohydrates': 3.12},
#  'Butter oil, anhydrous': {'calories': 876,
#   'fats': 99.0,
#   'proteins': 0.28,
#   'carbohydrates': 0.0},
#  'Chicory, raw, witloof': {'calories': 17,
#   'fats': 0.1,
#   'proteins': 0.9,
#   'carbohydrates': 4.0},
#  'KEEBLER, Waffle Cones': {'calories': 424,
#   'fats': 5.3,
#   'proteins': 6.5,
#   'carbohydrates': 87.7},
#  'KEEBLER, Waffle Bowls': {'calories': 424,
#   'fats': 5.3,
#   'proteins': 6.5,
#   'carbohydrates': 87.7},
#  'Broccoli, raw, leaves': {'calories': 28,
#   'fats': 0.4,
#   'proteins': 2.98,
#   'carbohydrates': 5.06},
#  'Durian, raw or frozen': {'calories': 147,
#   'fats': 5.3,
#   'proteins': 1.47,
#   'carbohydrates': 27.09},
#  'Tomatoes, raw, orange': {'calories': 16,
#   'fats': 0.2,
#   'proteins': 1.16,
#   'carbohydrates': 3.18},
#  'Tomatoes, raw, yellow': {'calories': 15,
#   'fats': 0.3,
#   'proteins': 0.98,
#   'carbohydrates': 2.98},
#  'Egg custards, dry mix': {'calories': 410,
#   'fats': 6.4,
#   'proteins': 6.9,
#   'carbohydrates': 82.8},
#  'Peanut flour, low fat': {'calories': 428,
#   'fats': 22.0,
#   'proteins': 33.8,
#   'carbohydrates': 31.27},
#  'Fish, smoked, haddock': {'calories': 116,
#   'fats': 1.0,
#   'proteins': 25.23,
#   'carbohydrates': 0.0},
#  "DENNY'S, french fries": {'calories': 282,
#   'fats': 14.0,
#   'proteins': 3.41,
#   'carbohydrates': 35.2},
#  'Ground turkey, cooked': {'calories': 203,
#   'fats': 10.0,
#   'proteins': 27.37,
#   'carbohydrates': 0.0},
#  'MURRAY, Vanilla Wafer': {'calories': 461,
#   'fats': 17.0,
#   'proteins': 4.0,
#   'carbohydrates': 72.9},
#  "WENDY'S, french fries": {'calories': 301,
#   'fats': 14.0,
#   'proteins': 3.73,
#   'carbohydrates': 39.73},
#  'Bread, toasted, wheat': {'calories': 313,
#   'fats': 4.3,
#   'proteins': 12.96,
#   'carbohydrates': 55.77},
#  'Danish pastry, cheese': {'calories': 374,
#   'fats': 22.0,
#   'proteins': 8.0,
#   'carbohydrates': 37.2},
#  'Nuts, glazed, walnuts': {'calories': 500,
#   'fats': 36.0,
#   'proteins': 8.28,
#   'carbohydrates': 47.59},
#  'Spices, garlic powder': {'calories': 331,
#   'fats': 0.7,
#   'proteins': 16.55,
#   'carbohydrates': 72.73},
#  'Oil, soybean lecithin': {'calories': 763,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Egg, fresh, raw, yolk': {'calories': 322,
#   'fats': 27.0,
#   'proteins': 15.86,
#   'carbohydrates': 3.59},
#  'Fireweed, raw, leaves': {'calories': 103,
#   'fats': 2.8,
#   'proteins': 4.71,
#   'carbohydrates': 19.22},
#  'Beef, pastrami, cured': {'calories': 147,
#   'fats': 5.8,
#   'proteins': 21.8,
#   'carbohydrates': 0.36},
#  'Frankfurter, meatless': {'calories': 233,
#   'fats': 14.0,
#   'proteins': 19.61,
#   'carbohydrates': 7.7},
#  'Emu, raw, flat fillet': {'calories': 102,
#   'fats': 0.7,
#   'proteins': 22.25,
#   'carbohydrates': 0.0},
#  'Emu, raw, inside drum': {'calories': 108,
#   'fats': 1.5,
#   'proteins': 22.22,
#   'carbohydrates': 0.0},
#  'Ice creams, chocolate': {'calories': 216,
#   'fats': 11.0,
#   'proteins': 3.8,
#   'carbohydrates': 28.2},
#  'Snacks, potato sticks': {'calories': 522,
#   'fats': 34.0,
#   'proteins': 6.7,
#   'carbohydrates': 53.3},
#  'USDA Commodity, salsa': {'calories': 36,
#   'fats': 0.2,
#   'proteins': 1.5,
#   'carbohydrates': 7.0},
#  'Figs, uncooked, dried': {'calories': 249,
#   'fats': 0.9,
#   'proteins': 3.3,
#   'carbohydrates': 63.87},
#  'Game meat, raw, horse': {'calories': 133,
#   'fats': 4.6,
#   'proteins': 21.39,
#   'carbohydrates': 0.0},
#  'Syrup, fruit flavored': {'calories': 261,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 65.1},
#  'Broccoli, raw, stalks': {'calories': 28,
#   'fats': 0.4,
#   'proteins': 2.98,
#   'carbohydrates': 5.24},
#  'Cream, cultured, sour': {'calories': 198,
#   'fats': 19.0,
#   'proteins': 2.44,
#   'carbohydrates': 4.63},
#  'Gravy, canned, au jus': {'calories': 16,
#   'fats': 0.2,
#   'proteins': 1.2,
#   'carbohydrates': 2.5},
#  "McDONALD'S, Hamburger": {'calories': 264,
#   'fats': 10.0,
#   'proteins': 12.92,
#   'carbohydrates': 30.28},
#  'Cheese, port de salut': {'calories': 352,
#   'fats': 28.0,
#   'proteins': 23.78,
#   'carbohydrates': 0.57},
#  'SILK Original Creamer': {'calories': 100,
#   'fats': 6.7,
#   'proteins': 0.0,
#   'carbohydrates': 6.67},
#  'SILK Hazelnut Creamer': {'calories': 133,
#   'fats': 6.7,
#   'proteins': 0.0,
#   'carbohydrates': 20.0},
#  'Soup, mix, dry, onion': {'calories': 293,
#   'fats': 0.3,
#   'proteins': 7.48,
#   'carbohydrates': 65.07},
#  'Mushrooms, raw, enoki': {'calories': 37,
#   'fats': 0.3,
#   'proteins': 2.66,
#   'carbohydrates': 7.81},
#  'Bacon and beef sticks': {'calories': 517,
#   'fats': 44.0,
#   'proteins': 29.1,
#   'carbohydrates': 0.8},
#  'Salami, pork, Italian': {'calories': 425,
#   'fats': 37.0,
#   'proteins': 21.7,
#   'carbohydrates': 1.2},
#  'Crackers, whole-wheat': {'calories': 427,
#   'fats': 14.0,
#   'proteins': 10.58,
#   'carbohydrates': 69.55},
#  'Peanuts, raw, spanish': {'calories': 570,
#   'fats': 50.0,
#   'proteins': 26.15,
#   'carbohydrates': 15.83},
#  'Hominy, white, canned': {'calories': 72,
#   'fats': 0.9,
#   'proteins': 1.48,
#   'carbohydrates': 14.26},
#  'Game meat, raw, moose': {'calories': 102,
#   'fats': 0.7,
#   'proteins': 22.24,
#   'carbohydrates': 0.0},
#  'Pears, red anjou, raw': {'calories': 62,
#   'fats': 0.1,
#   'proteins': 0.33,
#   'carbohydrates': 14.94},
#  'Horseradish, prepared': {'calories': 48,
#   'fats': 0.7,
#   'proteins': 1.18,
#   'carbohydrates': 11.29},
#  'Fish, raw, butterfish': {'calories': 146,
#   'fats': 8.0,
#   'proteins': 17.28,
#   'carbohydrates': 0.0},
#  'Lebanon bologna, beef': {'calories': 172,
#   'fats': 10.0,
#   'proteins': 19.03,
#   'carbohydrates': 0.44},
#  'Ham and cheese spread': {'calories': 245,
#   'fats': 19.0,
#   'proteins': 16.18,
#   'carbohydrates': 2.28},
#  'TACO BELL, Taco Salad': {'calories': 170,
#   'fats': 9.2,
#   'proteins': 6.69,
#   'carbohydrates': 15.1},
#  'Sauce, worcestershire': {'calories': 78,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 19.46},
#  'Candies, marshmallows': {'calories': 318,
#   'fats': 0.2,
#   'proteins': 1.8,
#   'carbohydrates': 81.3},
#  'Hummus, home prepared': {'calories': 177,
#   'fats': 8.6,
#   'proteins': 4.86,
#   'carbohydrates': 20.12},
#  'Horned melon (Kiwano)': {'calories': 44,
#   'fats': 1.3,
#   'proteins': 1.78,
#   'carbohydrates': 7.56},
#  'Ice cream sundae cone': {'calories': 254,
#   'fats': 14.0,
#   'proteins': 3.0,
#   'carbohydrates': 28.89},
#  'Peppers, raw, serrano': {'calories': 32,
#   'fats': 0.4,
#   'proteins': 1.74,
#   'carbohydrates': 6.7},
#  'Cabbage, cooked, napa': {'calories': 12,
#   'fats': 0.2,
#   'proteins': 1.1,
#   'carbohydrates': 2.23},
#  'Peppers, dried, ancho': {'calories': 281,
#   'fats': 8.2,
#   'proteins': 11.86,
#   'carbohydrates': 51.42},
#  'Parsley, freeze-dried': {'calories': 271,
#   'fats': 5.2,
#   'proteins': 31.3,
#   'carbohydrates': 42.38},
#  'Spices, black, pepper': {'calories': 251,
#   'fats': 3.3,
#   'proteins': 10.39,
#   'carbohydrates': 63.95},
#  'Spices, white, pepper': {'calories': 296,
#   'fats': 2.1,
#   'proteins': 10.4,
#   'carbohydrates': 68.61},
#  'Yambean (jicama), raw': {'calories': 38,
#   'fats': 0.1,
#   'proteins': 0.72,
#   'carbohydrates': 8.82},
#  'Nuts, dried, pilinuts': {'calories': 719,
#   'fats': 80.0,
#   'proteins': 10.8,
#   'carbohydrates': 3.98},
#  'Kiwifruit, raw, green': {'calories': 61,
#   'fats': 0.5,
#   'proteins': 1.14,
#   'carbohydrates': 14.66},
#  'Drumstick leaves, raw': {'calories': 64,
#   'fats': 1.4,
#   'proteins': 9.4,
#   'carbohydrates': 8.28},
#  'Yautia (tannier), raw': {'calories': 98,
#   'fats': 0.4,
#   'proteins': 1.46,
#   'carbohydrates': 23.63},
#  'Candies, butterscotch': {'calories': 391,
#   'fats': 3.3,
#   'proteins': 0.03,
#   'carbohydrates': 90.4},
#  'Cucumber, raw, peeled': {'calories': 12,
#   'fats': 0.2,
#   'proteins': 0.59,
#   'carbohydrates': 2.16},
#  'Dandelion greens, raw': {'calories': 45,
#   'fats': 0.7,
#   'proteins': 2.7,
#   'carbohydrates': 9.2},
#  'Melons, raw, honeydew': {'calories': 36,
#   'fats': 0.1,
#   'proteins': 0.54,
#   'carbohydrates': 9.09},
#  'Potato salad with egg': {'calories': 157,
#   'fats': 9.4,
#   'proteins': 1.96,
#   'carbohydrates': 16.18},
#  'Mushrooms, raw, white': {'calories': 22,
#   'fats': 0.3,
#   'proteins': 3.09,
#   'carbohydrates': 3.26},
#  'Mushrooms, raw, morel': {'calories': 31,
#   'fats': 0.6,
#   'proteins': 3.12,
#   'carbohydrates': 5.1},
#  'Cheese, Mexican blend': {'calories': 358,
#   'fats': 29.0,
#   'proteins': 23.54,
#   'carbohydrates': 1.75},
#  'Oranges, Florida, raw': {'calories': 46,
#   'fats': 0.2,
#   'proteins': 0.7,
#   'carbohydrates': 11.54},
#  'SILK Vanilla, soymilk': {'calories': 41,
#   'fats': 1.4,
#   'proteins': 2.47,
#   'carbohydrates': 4.12},
#  'Papaya nectar, canned': {'calories': 57,
#   'fats': 0.2,
#   'proteins': 0.17,
#   'carbohydrates': 14.51},
#  'Fiddlehead ferns, raw': {'calories': 34,
#   'fats': 0.4,
#   'proteins': 4.55,
#   'carbohydrates': 5.54},
#  'SILK Peach soy yogurt': {'calories': 94,
#   'fats': 1.2,
#   'proteins': 2.35,
#   'carbohydrates': 18.82},
#  'SILK Plain soy yogurt': {'calories': 66,
#   'fats': 1.8,
#   'proteins': 2.64,
#   'carbohydrates': 9.69},
#  'PACE, Enchilada Sauce': {'calories': 40,
#   'fats': 0.0,
#   'proteins': 1.67,
#   'carbohydrates': 8.33},
#  'Yeast extract spread': {'calories': 185,
#   'fats': 0.9,
#   'proteins': 23.88,
#   'carbohydrates': 20.42},
#  'Tomatoes, raw, green': {'calories': 23,
#   'fats': 0.2,
#   'proteins': 1.2,
#   'carbohydrates': 5.1},
#  'Mollusks, raw, snail': {'calories': 90,
#   'fats': 1.4,
#   'proteins': 16.1,
#   'carbohydrates': 2.0},
#  'Emu, raw, fan fillet': {'calories': 103,
#   'fats': 0.8,
#   'proteins': 22.5,
#   'carbohydrates': 0.0},
#  'Pasta, enriched, dry': {'calories': 371,
#   'fats': 1.5,
#   'proteins': 13.04,
#   'carbohydrates': 74.67},
#  'Cookies, gingersnaps': {'calories': 416,
#   'fats': 9.8,
#   'proteins': 5.6,
#   'carbohydrates': 76.9},
#  'Sour cream, fat free': {'calories': 74,
#   'fats': 0.0,
#   'proteins': 3.1,
#   'carbohydrates': 15.6},
#  'MURRAY, Honey Graham': {'calories': 445,
#   'fats': 13.0,
#   'proteins': 5.9,
#   'carbohydrates': 75.7},
#  'Frankfurter, chicken': {'calories': 223,
#   'fats': 16.0,
#   'proteins': 15.51,
#   'carbohydrates': 2.74},
#  'Ham, canned, chopped': {'calories': 239,
#   'fats': 19.0,
#   'proteins': 16.06,
#   'carbohydrates': 0.26},
#  'Spices, dried, thyme': {'calories': 276,
#   'fats': 7.4,
#   'proteins': 9.11,
#   'carbohydrates': 63.94},
#  'Carrot juice, canned': {'calories': 40,
#   'fats': 0.2,
#   'proteins': 0.95,
#   'carbohydrates': 9.28},
#  'Corn, dried (Navajo)': {'calories': 386,
#   'fats': 5.2,
#   'proteins': 9.88,
#   'carbohydrates': 74.93},
#  'Pate, truffle flavor': {'calories': 327,
#   'fats': 29.0,
#   'proteins': 11.2,
#   'carbohydrates': 6.3},
#  'Fruit butters, apple': {'calories': 173,
#   'fats': 0.3,
#   'proteins': 0.39,
#   'carbohydrates': 42.47},
#  'Fast foods, coleslaw': {'calories': 153,
#   'fats': 9.9,
#   'proteins': 0.95,
#   'carbohydrates': 14.89},
#  'Salami, beef, cooked': {'calories': 261,
#   'fats': 22.0,
#   'proteins': 12.6,
#   'carbohydrates': 1.9},
#  'Spices, chili powder': {'calories': 282,
#   'fats': 14.0,
#   'proteins': 13.46,
#   'carbohydrates': 49.7},
#  'Spices, caraway seed': {'calories': 333,
#   'fats': 15.0,
#   'proteins': 19.77,
#   'carbohydrates': 49.9},
#  'Spices, dried, basil': {'calories': 233,
#   'fats': 4.1,
#   'proteins': 22.98,
#   'carbohydrates': 47.75},
#  'Pickle relish, sweet': {'calories': 130,
#   'fats': 0.5,
#   'proteins': 0.37,
#   'carbohydrates': 35.06},
#  'Chives, freeze-dried': {'calories': 311,
#   'fats': 3.5,
#   'proteins': 21.2,
#   'carbohydrates': 64.29},
#  'Fish, raw, sablefish': {'calories': 195,
#   'fats': 15.0,
#   'proteins': 13.41,
#   'carbohydrates': 0.0},
#  'Crackers, multigrain': {'calories': 482,
#   'fats': 20.0,
#   'proteins': 7.1,
#   'carbohydrates': 67.6},
#  'Spices, ground, mace': {'calories': 475,
#   'fats': 32.0,
#   'proteins': 6.71,
#   'carbohydrates': 50.5},
#  'Spices, onion powder': {'calories': 341,
#   'fats': 1.0,
#   'proteins': 10.41,
#   'carbohydrates': 79.12},
#  'Butter, without salt': {'calories': 717,
#   'fats': 81.0,
#   'proteins': 0.85,
#   'carbohydrates': 0.06},
#  'Rice noodles, cooked': {'calories': 108,
#   'fats': 0.2,
#   'proteins': 1.79,
#   'carbohydrates': 24.01},
#  'Barley flour or meal': {'calories': 345,
#   'fats': 1.6,
#   'proteins': 10.5,
#   'carbohydrates': 74.52},
#  'Sesbania flower, raw': {'calories': 27,
#   'fats': 0.0,
#   'proteins': 1.28,
#   'carbohydrates': 6.73},
#  'Garlic bread, frozen': {'calories': 350,
#   'fats': 17.0,
#   'proteins': 8.36,
#   'carbohydrates': 41.72},
#  'KFC, Popcorn Chicken': {'calories': 351,
#   'fats': 22.0,
#   'proteins': 17.67,
#   'carbohydrates': 21.18},
#  "APPLEBEE'S, coleslaw": {'calories': 120,
#   'fats': 7.1,
#   'proteins': 0.79,
#   'carbohydrates': 13.17},
#  'Rolls, sweet, dinner': {'calories': 321,
#   'fats': 7.4,
#   'proteins': 10.04,
#   'carbohydrates': 53.58},
#  'Cherries, raw, sweet': {'calories': 63,
#   'fats': 0.2,
#   'proteins': 1.06,
#   'carbohydrates': 16.01},
#  'Ostrich, raw, ground': {'calories': 165,
#   'fats': 8.7,
#   'proteins': 20.22,
#   'carbohydrates': 0.0},
#  'SILK Coffee, soymilk': {'calories': 62,
#   'fats': 1.4,
#   'proteins': 2.06,
#   'carbohydrates': 10.29},
#  'Snacks, banana chips': {'calories': 519,
#   'fats': 34.0,
#   'proteins': 2.3,
#   'carbohydrates': 58.4},
#  'Peaches, raw, yellow': {'calories': 39,
#   'fats': 0.3,
#   'proteins': 0.91,
#   'carbohydrates': 9.54},
#  'Rolls, wheat, dinner': {'calories': 273,
#   'fats': 6.3,
#   'proteins': 8.6,
#   'carbohydrates': 46.0},
#  'Candies, HEATH BITES': {'calories': 530,
#   'fats': 30.0,
#   'proteins': 3.94,
#   'carbohydrates': 63.39},
#  'Chicken, raw, ground': {'calories': 143,
#   'fats': 8.1,
#   'proteins': 17.44,
#   'carbohydrates': 0.04},
#  'Pears, bartlett, raw': {'calories': 63,
#   'fats': 0.2,
#   'proteins': 0.39,
#   'carbohydrates': 15.01},
#  'Toppings, strawberry': {'calories': 254,
#   'fats': 0.1,
#   'proteins': 0.2,
#   'carbohydrates': 66.3},
#  'KEEBLER, Sugar Cones': {'calories': 375,
#   'fats': 3.7,
#   'proteins': 7.3,
#   'carbohydrates': 78.0},
#  'Seaweed, raw, wakame': {'calories': 45,
#   'fats': 0.6,
#   'proteins': 3.03,
#   'carbohydrates': 9.14},
#  'Seaweed, dried, agar': {'calories': 306,
#   'fats': 0.3,
#   'proteins': 6.21,
#   'carbohydrates': 80.88},
#  'Bread, cracked-wheat': {'calories': 260,
#   'fats': 3.9,
#   'proteins': 8.7,
#   'carbohydrates': 49.5},
#  'Amaranth leaves, raw': {'calories': 23,
#   'fats': 0.3,
#   'proteins': 2.46,
#   'carbohydrates': 4.02},
#  'Barley, raw, pearled': {'calories': 352,
#   'fats': 1.2,
#   'proteins': 9.91,
#   'carbohydrates': 77.72},
#  'Polish sausage, pork': {'calories': 326,
#   'fats': 29.0,
#   'proteins': 14.1,
#   'carbohydrates': 1.63},
#  'Spices, curry powder': {'calories': 325,
#   'fats': 14.0,
#   'proteins': 14.29,
#   'carbohydrates': 55.83},
#  'Bacon bits, meatless': {'calories': 476,
#   'fats': 26.0,
#   'proteins': 32.0,
#   'carbohydrates': 28.6},
#  'Semolina, unenriched': {'calories': 360,
#   'fats': 1.1,
#   'proteins': 12.68,
#   'carbohydrates': 72.83},
#  'Grape leaves, canned': {'calories': 69,
#   'fats': 2.0,
#   'proteins': 4.27,
#   'carbohydrates': 11.71},
#  'Spices, ground, sage': {'calories': 315,
#   'fats': 13.0,
#   'proteins': 10.63,
#   'carbohydrates': 60.73},
#  'PACE, Red Taco Sauce': {'calories': 50,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 12.5},
#  "DENNY'S, hash browns": {'calories': 197,
#   'fats': 9.0,
#   'proteins': 2.49,
#   'carbohydrates': 26.59},
#  "DENNY'S, onion rings": {'calories': 385,
#   'fats': 22.0,
#   'proteins': 5.29,
#   'carbohydrates': 41.05},
#  'Ostrich, raw, oyster': {'calories': 125,
#   'fats': 3.7,
#   'proteins': 21.55,
#   'carbohydrates': 0.0},
#  'Oil, corn and canola': {'calories': 884,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Pumpkin flowers, raw': {'calories': 15,
#   'fats': 0.1,
#   'proteins': 1.03,
#   'carbohydrates': 3.28},
#  'Celery flakes, dried': {'calories': 319,
#   'fats': 2.1,
#   'proteins': 11.3,
#   'carbohydrates': 63.7},
#  'Crackers, egg, matzo': {'calories': 391,
#   'fats': 2.1,
#   'proteins': 12.3,
#   'carbohydrates': 78.6},
#  'Loganberries, frozen': {'calories': 55,
#   'fats': 0.3,
#   'proteins': 1.52,
#   'carbohydrates': 13.02},
#  'Tangerine juice, raw': {'calories': 43,
#   'fats': 0.2,
#   'proteins': 0.5,
#   'carbohydrates': 10.1},
#  'Soybeans, raw, green': {'calories': 147,
#   'fats': 6.8,
#   'proteins': 12.95,
#   'carbohydrates': 11.05},
#  'Soybean, curd cheese': {'calories': 151,
#   'fats': 8.1,
#   'proteins': 12.5,
#   'carbohydrates': 6.9},
#  'Game meat, raw, bear': {'calories': 161,
#   'fats': 8.3,
#   'proteins': 20.1,
#   'carbohydrates': 0.0},
#  'Game meat, raw, deer': {'calories': 120,
#   'fats': 2.4,
#   'proteins': 22.96,
#   'carbohydrates': 0.0},
#  'Oranges, navels, raw': {'calories': 49,
#   'fats': 0.2,
#   'proteins': 0.91,
#   'carbohydrates': 12.54},
#  'Tostada shells, corn': {'calories': 474,
#   'fats': 23.0,
#   'proteins': 6.15,
#   'carbohydrates': 64.43},
#  'Fish, raw, swordfish': {'calories': 144,
#   'fats': 6.7,
#   'proteins': 19.66,
#   'carbohydrates': 0.0},
#  'Taro, raw, tahitian': {'calories': 44,
#   'fats': 1.0,
#   'proteins': 2.79,
#   'carbohydrates': 6.91},
#  'Chicory greens, raw': {'calories': 23,
#   'fats': 0.3,
#   'proteins': 1.7,
#   'carbohydrates': 4.7},
#  'Hearts of palm, raw': {'calories': 115,
#   'fats': 0.2,
#   'proteins': 2.7,
#   'carbohydrates': 25.61},
#  'Chayote, raw, fruit': {'calories': 19,
#   'fats': 0.1,
#   'proteins': 0.82,
#   'carbohydrates': 4.51},
#  'Fish, smoked, cisco': {'calories': 177,
#   'fats': 12.0,
#   'proteins': 16.36,
#   'carbohydrates': 0.0},
#  'Frankfurter, turkey': {'calories': 223,
#   'fats': 17.0,
#   'proteins': 12.23,
#   'carbohydrates': 3.81},
#  'Candies, jellybeans': {'calories': 375,
#   'fats': 0.1,
#   'proteins': 0.0,
#   'carbohydrates': 93.55},
#  'Oil, ucuhuba butter': {'calories': 884,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Soy protein isolate': {'calories': 335,
#   'fats': 3.4,
#   'proteins': 88.32,
#   'carbohydrates': 0.0},
#  'Syrups, light, corn': {'calories': 283,
#   'fats': 0.2,
#   'proteins': 0.0,
#   'carbohydrates': 76.79},
#  'Fish, raw, milkfish': {'calories': 148,
#   'fats': 6.7,
#   'proteins': 20.53,
#   'carbohydrates': 0.0},
#  'Fish, raw, monkfish': {'calories': 76,
#   'fats': 1.5,
#   'proteins': 14.48,
#   'carbohydrates': 0.0},
#  "Mother's loaf, pork": {'calories': 282,
#   'fats': 22.0,
#   'proteins': 12.07,
#   'carbohydrates': 7.53},
#  'Tapioca, dry, pearl': {'calories': 358,
#   'fats': 0.0,
#   'proteins': 0.19,
#   'carbohydrates': 88.69},
#  'Guavas, raw, common': {'calories': 68,
#   'fats': 1.0,
#   'proteins': 2.55,
#   'carbohydrates': 14.32},
#  'Spices, celery seed': {'calories': 392,
#   'fats': 25.0,
#   'proteins': 18.07,
#   'carbohydrates': 41.35},
#  'Candies, peanut bar': {'calories': 522,
#   'fats': 34.0,
#   'proteins': 15.5,
#   'carbohydrates': 47.4},
#  'Bread, toasted, rye': {'calories': 284,
#   'fats': 3.6,
#   'proteins': 9.4,
#   'carbohydrates': 53.1},
#  'Oil, apricot kernel': {'calories': 884,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Candies, YORK BITES': {'calories': 394,
#   'fats': 7.3,
#   'proteins': 1.78,
#   'carbohydrates': 81.64},
#  'Meatballs, meatless': {'calories': 197,
#   'fats': 9.0,
#   'proteins': 21.0,
#   'carbohydrates': 8.0},
#  'Emu, raw, full rump': {'calories': 112,
#   'fats': 1.6,
#   'proteins': 22.83,
#   'carbohydrates': 0.0},
#  'Mustard greens, raw': {'calories': 27,
#   'fats': 0.4,
#   'proteins': 2.86,
#   'carbohydrates': 4.67},
#  'Seaweed, raw, laver': {'calories': 35,
#   'fats': 0.3,
#   'proteins': 5.81,
#   'carbohydrates': 5.11},
#  'Sweet rolls, cheese': {'calories': 360,
#   'fats': 18.0,
#   'proteins': 7.1,
#   'carbohydrates': 43.7},
#  'Figs, stewed, dried': {'calories': 107,
#   'fats': 0.4,
#   'proteins': 1.42,
#   'carbohydrates': 27.57},
#  'Bread sticks, plain': {'calories': 412,
#   'fats': 9.5,
#   'proteins': 12.0,
#   'carbohydrates': 68.4},
#  'SILK Mocha, soymilk': {'calories': 58,
#   'fats': 1.4,
#   'proteins': 2.06,
#   'carbohydrates': 9.05},
#  'Milk and cereal bar': {'calories': 413,
#   'fats': 11.0,
#   'proteins': 6.47,
#   'carbohydrates': 72.05},
#  'Bread, pumpernickel': {'calories': 250,
#   'fats': 3.1,
#   'proteins': 8.7,
#   'carbohydrates': 47.5},
#  'Game meat, raw, elk': {'calories': 111,
#   'fats': 1.5,
#   'proteins': 22.95,
#   'carbohydrates': 0.0},
#  'PACE, Pico De Gallo': {'calories': 31,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 9.38},
#  'Ostrich, raw, round': {'calories': 116,
#   'fats': 2.4,
#   'proteins': 21.99,
#   'carbohydrates': 0.0},
#  'HORMEL, Cure 81 Ham': {'calories': 106,
#   'fats': 3.6,
#   'proteins': 18.43,
#   'carbohydrates': 0.21},
#  'Prune juice, canned': {'calories': 71,
#   'fats': 0.0,
#   'proteins': 0.61,
#   'carbohydrates': 17.45},
#  "McDONALD'S, BIG MAC": {'calories': 257,
#   'fats': 15.0,
#   'proteins': 11.82,
#   'carbohydrates': 20.08},
#  'Soy flour, defatted': {'calories': 327,
#   'fats': 1.2,
#   'proteins': 51.46,
#   'carbohydrates': 33.92},
#  'Bread, toasted, egg': {'calories': 315,
#   'fats': 6.6,
#   'proteins': 10.5,
#   'carbohydrates': 52.6},
#  'Fish, raw, mahimahi': {'calories': 85,
#   'fats': 0.7,
#   'proteins': 18.5,
#   'carbohydrates': 0.0},
#  'Fish, raw, bluefish': {'calories': 124,
#   'fats': 4.2,
#   'proteins': 20.04,
#   'carbohydrates': 0.0},
#  'Spices, fennel seed': {'calories': 345,
#   'fats': 15.0,
#   'proteins': 15.8,
#   'carbohydrates': 52.29},
#  'Potatoes, skin, raw': {'calories': 58,
#   'fats': 0.1,
#   'proteins': 2.57,
#   'carbohydrates': 12.44},
#  'Pepper, raw, banana': {'calories': 27,
#   'fats': 0.5,
#   'proteins': 1.66,
#   'carbohydrates': 5.35},
#  'Drumstick pods, raw': {'calories': 37,
#   'fats': 0.2,
#   'proteins': 2.1,
#   'carbohydrates': 8.53},
#  'Toppings, pineapple': {'calories': 253,
#   'fats': 0.1,
#   'proteins': 0.1,
#   'carbohydrates': 66.4},
#  'Acorn stew (Apache)': {'calories': 95,
#   'fats': 3.5,
#   'proteins': 6.81,
#   'carbohydrates': 9.22},
#  'Tomatoes, sun-dried': {'calories': 258,
#   'fats': 3.0,
#   'proteins': 14.11,
#   'carbohydrates': 55.76},
#  'Guava sauce, cooked': {'calories': 36,
#   'fats': 0.1,
#   'proteins': 0.32,
#   'carbohydrates': 9.48},
#  'Pumpkin leaves, raw': {'calories': 19,
#   'fats': 0.4,
#   'proteins': 3.15,
#   'carbohydrates': 2.33},
#  'Melons, raw, casaba': {'calories': 28,
#   'fats': 0.1,
#   'proteins': 1.11,
#   'carbohydrates': 6.58},
#  'Melon balls, frozen': {'calories': 33,
#   'fats': 0.3,
#   'proteins': 0.84,
#   'carbohydrates': 7.94},
#  'Fish oil, cod liver': {'calories': 902,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Nuts, dried, acorns': {'calories': 509,
#   'fats': 31.0,
#   'proteins': 8.1,
#   'carbohydrates': 53.66},
#  'Rolls, pumpernickel': {'calories': 276,
#   'fats': 2.8,
#   'proteins': 10.8,
#   'carbohydrates': 51.87},
#  'Gravy, dry, chicken': {'calories': 381,
#   'fats': 9.7,
#   'proteins': 11.27,
#   'carbohydrates': 62.09},
#  'Fish, raw, tilefish': {'calories': 96,
#   'fats': 2.3,
#   'proteins': 17.5,
#   'carbohydrates': 0.0},
#  'Ice creams, vanilla': {'calories': 207,
#   'fats': 11.0,
#   'proteins': 3.5,
#   'carbohydrates': 23.6},
#  'SILK Plain, soymilk': {'calories': 41,
#   'fats': 1.7,
#   'proteins': 2.88,
#   'carbohydrates': 3.29},
#  'Cabbage, raw, savoy': {'calories': 27,
#   'fats': 0.1,
#   'proteins': 2.0,
#   'carbohydrates': 6.1},
#  'Fish, raw, tilapia': {'calories': 96,
#   'fats': 1.7,
#   'proteins': 20.08,
#   'carbohydrates': 0.0},
#  'Broccoli raab, raw': {'calories': 22,
#   'fats': 0.5,
#   'proteins': 3.17,
#   'carbohydrates': 2.85},
#  'Corn grain, yellow': {'calories': 365,
#   'fats': 4.7,
#   'proteins': 9.42,
#   'carbohydrates': 74.26},
#  'Turtle, raw, green': {'calories': 89,
#   'fats': 0.5,
#   'proteins': 19.8,
#   'carbohydrates': 0.0},
#  'Chicory roots, raw': {'calories': 72,
#   'fats': 0.2,
#   'proteins': 1.4,
#   'carbohydrates': 17.51},
#  'Ice cream sandwich': {'calories': 237,
#   'fats': 8.6,
#   'proteins': 4.29,
#   'carbohydrates': 37.14},
#  'Croutons, seasoned': {'calories': 465,
#   'fats': 18.0,
#   'proteins': 10.8,
#   'carbohydrates': 63.5},
#  'Snacks, taro chips': {'calories': 498,
#   'fats': 25.0,
#   'proteins': 2.3,
#   'carbohydrates': 68.1},
#  'Prickly pears, raw': {'calories': 41,
#   'fats': 0.5,
#   'proteins': 0.73,
#   'carbohydrates': 9.57},
#  'Fish, raw, haddock': {'calories': 74,
#   'fats': 0.5,
#   'proteins': 16.32,
#   'carbohydrates': 0.0},
#  'Liver cheese, pork': {'calories': 304,
#   'fats': 26.0,
#   'proteins': 15.2,
#   'carbohydrates': 2.1},
#  'Ground turkey, raw': {'calories': 148,
#   'fats': 7.7,
#   'proteins': 19.66,
#   'carbohydrates': 0.0},
#  'Jams and preserves': {'calories': 278,
#   'fats': 0.1,
#   'proteins': 0.37,
#   'carbohydrates': 68.86},
#  'Carrots, raw, baby': {'calories': 35,
#   'fats': 0.1,
#   'proteins': 0.64,
#   'carbohydrates': 8.24},
#  'Oil, nutmeg butter': {'calories': 884,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Semolina, enriched': {'calories': 360,
#   'fats': 1.1,
#   'proteins': 12.68,
#   'carbohydrates': 72.83},
#  'Spices, anise seed': {'calories': 337,
#   'fats': 16.0,
#   'proteins': 17.6,
#   'carbohydrates': 50.02},
#  'Snacks, corn cakes': {'calories': 387,
#   'fats': 2.4,
#   'proteins': 8.1,
#   'carbohydrates': 83.4},
#  'Catsup, low sodium': {'calories': 101,
#   'fats': 0.1,
#   'proteins': 1.04,
#   'carbohydrates': 27.4},
#  'Croissants, cheese': {'calories': 414,
#   'fats': 21.0,
#   'proteins': 9.2,
#   'carbohydrates': 47.0},
#  'Milk, fluid, sheep': {'calories': 108,
#   'fats': 7.0,
#   'proteins': 5.98,
#   'carbohydrates': 5.36},
#  'Acerola juice, raw': {'calories': 23,
#   'fats': 0.3,
#   'proteins': 0.4,
#   'carbohydrates': 4.8},
#  'Jute, raw, potherb': {'calories': 34,
#   'fats': 0.3,
#   'proteins': 4.65,
#   'carbohydrates': 5.8},
#  'Fast food, biscuit': {'calories': 370,
#   'fats': 19.0,
#   'proteins': 7.08,
#   'carbohydrates': 42.82},
#  'Bagels, multigrain': {'calories': 241,
#   'fats': 1.2,
#   'proteins': 9.9,
#   'carbohydrates': 47.47},
#  'Beef, dried, cured': {'calories': 153,
#   'fats': 1.9,
#   'proteins': 31.1,
#   'carbohydrates': 2.76},
#  'Nuts, almond paste': {'calories': 458,
#   'fats': 28.0,
#   'proteins': 9.0,
#   'carbohydrates': 47.81},
#  'Seaweed, raw, kelp': {'calories': 43,
#   'fats': 0.6,
#   'proteins': 1.68,
#   'carbohydrates': 9.57},
#  'Seaweed, raw, agar': {'calories': 26,
#   'fats': 0.0,
#   'proteins': 0.54,
#   'carbohydrates': 6.75},
#  'Fish oil, menhaden': {'calories': 902,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Rolls, egg, dinner': {'calories': 307,
#   'fats': 6.4,
#   'proteins': 9.5,
#   'carbohydrates': 52.0},
#  'Bread, white wheat': {'calories': 238,
#   'fats': 2.2,
#   'proteins': 10.66,
#   'carbohydrates': 43.91},
#  'Onions, raw, sweet': {'calories': 32,
#   'fats': 0.1,
#   'proteins': 0.8,
#   'carbohydrates': 7.55},
#  'Onions, raw, welsh': {'calories': 34,
#   'fats': 0.4,
#   'proteins': 1.9,
#   'carbohydrates': 6.5},
#  'SILK Chai, soymilk': {'calories': 53,
#   'fats': 1.4,
#   'proteins': 2.47,
#   'carbohydrates': 7.82},
#  'Rolls, rye, dinner': {'calories': 286,
#   'fats': 3.4,
#   'proteins': 10.3,
#   'carbohydrates': 53.1},
#  'Gravy, dry, au jus': {'calories': 313,
#   'fats': 9.6,
#   'proteins': 9.2,
#   'carbohydrates': 47.49},
#  'Cheese, neufchatel': {'calories': 253,
#   'fats': 23.0,
#   'proteins': 9.15,
#   'carbohydrates': 3.59},
#  'Hummus, commercial': {'calories': 166,
#   'fats': 9.6,
#   'proteins': 7.9,
#   'carbohydrates': 14.29},
#  'Croissants, butter': {'calories': 406,
#   'fats': 21.0,
#   'proteins': 8.2,
#   'carbohydrates': 45.8},
#  'Carrot, dehydrated': {'calories': 341,
#   'fats': 1.5,
#   'proteins': 8.1,
#   'carbohydrates': 79.57},
#  'Vinegar, distilled': {'calories': 18,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.04},
#  'Sapote, raw, mamey': {'calories': 124,
#   'fats': 0.5,
#   'proteins': 1.45,
#   'carbohydrates': 32.1},
#  'Soy flour, low-fat': {'calories': 372,
#   'fats': 8.9,
#   'proteins': 49.81,
#   'carbohydrates': 30.63},
#  'Syrups, sugar free': {'calories': 52,
#   'fats': 0.0,
#   'proteins': 0.8,
#   'carbohydrates': 12.13},
#  'Syrups, dark, corn': {'calories': 286,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 77.59},
#  'Taco shells, baked': {'calories': 476,
#   'fats': 22.0,
#   'proteins': 6.41,
#   'carbohydrates': 63.49},
#  'Spices, cumin seed': {'calories': 375,
#   'fats': 22.0,
#   'proteins': 17.81,
#   'carbohydrates': 44.24},
#  'Bamboo shoots, raw': {'calories': 27,
#   'fats': 0.3,
#   'proteins': 2.6,
#   'carbohydrates': 5.2},
#  'Fish, raw, lingcod': {'calories': 85,
#   'fats': 1.1,
#   'proteins': 17.66,
#   'carbohydrates': 0.0},
#  'Whey, dried, sweet': {'calories': 353,
#   'fats': 1.1,
#   'proteins': 12.93,
#   'carbohydrates': 74.46},
#  'Whey, fluid, sweet': {'calories': 27,
#   'fats': 0.4,
#   'proteins': 0.85,
#   'carbohydrates': 5.14},
#  'Spices, poppy seed': {'calories': 525,
#   'fats': 42.0,
#   'proteins': 17.99,
#   'carbohydrates': 28.13},
#  'Babyfood, pretzels': {'calories': 397,
#   'fats': 2.0,
#   'proteins': 10.8,
#   'carbohydrates': 82.2},
#  'Fat, mutton tallow': {'calories': 902,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Coffeecake, cheese': {'calories': 339,
#   'fats': 15.0,
#   'proteins': 7.0,
#   'carbohydrates': 44.3},
#  'Sauce, horseradish': {'calories': 503,
#   'fats': 51.0,
#   'proteins': 1.09,
#   'carbohydrates': 10.05},
#  'Yardlong bean, raw': {'calories': 47,
#   'fats': 0.4,
#   'proteins': 2.8,
#   'carbohydrates': 8.35},
#  'Cress, raw, garden': {'calories': 32,
#   'fats': 0.7,
#   'proteins': 2.6,
#   'carbohydrates': 5.5},
#  'Dates, deglet noor': {'calories': 282,
#   'fats': 0.4,
#   'proteins': 2.45,
#   'carbohydrates': 75.03},
#  'Lambsquarters, raw': {'calories': 43,
#   'fats': 0.8,
#   'proteins': 4.2,
#   'carbohydrates': 7.3},
#  'Gravy, dry, turkey': {'calories': 367,
#   'fats': 7.2,
#   'proteins': 10.42,
#   'carbohydrates': 65.12},
#  'Vital wheat gluten': {'calories': 370,
#   'fats': 1.9,
#   'proteins': 75.16,
#   'carbohydrates': 13.79},
#  'Turnip greens, raw': {'calories': 32,
#   'fats': 0.3,
#   'proteins': 1.5,
#   'carbohydrates': 7.13},
#  'Sugars, granulated': {'calories': 387,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 99.98},
#  'Frankfurter, pork': {'calories': 269,
#   'fats': 24.0,
#   'proteins': 12.81,
#   'carbohydrates': 0.28},
#  'Pomegranates, raw': {'calories': 83,
#   'fats': 1.2,
#   'proteins': 1.67,
#   'carbohydrates': 18.7},
#  'Pears, raw, asian': {'calories': 42,
#   'fats': 0.2,
#   'proteins': 0.5,
#   'carbohydrates': 10.65},
#  'Cookies, molasses': {'calories': 430,
#   'fats': 13.0,
#   'proteins': 5.6,
#   'carbohydrates': 73.8},
#  'Cookies, fig bars': {'calories': 348,
#   'fats': 7.3,
#   'proteins': 3.7,
#   'carbohydrates': 70.9},
#  'Liverwurst spread': {'calories': 305,
#   'fats': 25.0,
#   'proteins': 12.38,
#   'carbohydrates': 5.89},
#  'Roast beef spread': {'calories': 223,
#   'fats': 16.0,
#   'proteins': 15.27,
#   'carbohydrates': 3.73},
#  'Chard, raw, swiss': {'calories': 19,
#   'fats': 0.2,
#   'proteins': 1.8,
#   'carbohydrates': 3.74},
#  'Goose, raw, liver': {'calories': 133,
#   'fats': 4.3,
#   'proteins': 16.37,
#   'carbohydrates': 6.32},
#  'TACO BELL, Nachos': {'calories': 350,
#   'fats': 22.0,
#   'proteins': 4.32,
#   'carbohydrates': 34.91},
#  'Sausage, meatless': {'calories': 255,
#   'fats': 18.0,
#   'proteins': 20.28,
#   'carbohydrates': 8.09},
#  'Frankfurter, meat': {'calories': 290,
#   'fats': 26.0,
#   'proteins': 10.26,
#   'carbohydrates': 4.17},
#  'Rice flour, brown': {'calories': 363,
#   'fats': 2.8,
#   'proteins': 7.23,
#   'carbohydrates': 76.48},
#  'Peppermint, fresh': {'calories': 70,
#   'fats': 0.9,
#   'proteins': 3.75,
#   'carbohydrates': 14.89},
#  'Vinegar, red wine': {'calories': 19,
#   'fats': 0.0,
#   'proteins': 0.04,
#   'carbohydrates': 0.27},
#  'Vinegar, balsamic': {'calories': 88,
#   'fats': 0.0,
#   'proteins': 0.49,
#   'carbohydrates': 17.03},
#  'Luxury loaf, pork': {'calories': 141,
#   'fats': 4.8,
#   'proteins': 18.4,
#   'carbohydrates': 4.9},
#  'Rye flour, medium': {'calories': 349,
#   'fats': 1.5,
#   'proteins': 10.88,
#   'carbohydrates': 75.43},
#  "DENNY'S, coleslaw": {'calories': 183,
#   'fats': 15.0,
#   'proteins': 0.97,
#   'carbohydrates': 10.88},
#  'Bread, wheat bran': {'calories': 248,
#   'fats': 3.4,
#   'proteins': 8.8,
#   'carbohydrates': 47.8},
#  'Croissants, apple': {'calories': 254,
#   'fats': 8.7,
#   'proteins': 7.4,
#   'carbohydrates': 37.1},
#  'Candies, Tamarind': {'calories': 368,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 91.96},
#  'Oheloberries, raw': {'calories': 28,
#   'fats': 0.2,
#   'proteins': 0.38,
#   'carbohydrates': 6.84},
#  'PACE, Salsa Verde': {'calories': 47,
#   'fats': 1.6,
#   'proteins': 0.0,
#   'carbohydrates': 6.25},
#  'Barley malt flour': {'calories': 361,
#   'fats': 1.8,
#   'proteins': 10.28,
#   'carbohydrates': 78.3},
#  'Rice noodles, dry': {'calories': 364,
#   'fats': 0.6,
#   'proteins': 5.95,
#   'carbohydrates': 80.18},
#  'Fish oil, sardine': {'calories': 902,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Fish oil, herring': {'calories': 902,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Plantains, cooked': {'calories': 116,
#   'fats': 0.2,
#   'proteins': 0.79,
#   'carbohydrates': 31.15},
#  'Burdock root, raw': {'calories': 72,
#   'fats': 0.2,
#   'proteins': 1.53,
#   'carbohydrates': 17.34},
#  'Butterbur, canned': {'calories': 3,
#   'fats': 0.1,
#   'proteins': 0.11,
#   'carbohydrates': 0.38},
#  'Ostrich, raw, fan': {'calories': 117,
#   'fats': 2.7,
#   'proteins': 21.81,
#   'carbohydrates': 0.0},
#  'SILK Nog, soymilk': {'calories': 74,
#   'fats': 1.6,
#   'proteins': 2.46,
#   'carbohydrates': 12.3},
#  'Gravy, dry, brown': {'calories': 367,
#   'fats': 9.6,
#   'proteins': 10.74,
#   'carbohydrates': 59.38},
#  'Cheese, provolone': {'calories': 351,
#   'fats': 27.0,
#   'proteins': 25.58,
#   'carbohydrates': 2.14},
#  'Cheese, roquefort': {'calories': 369,
#   'fats': 31.0,
#   'proteins': 21.54,
#   'carbohydrates': 2.0},
#  'Muffins, oat bran': {'calories': 270,
#   'fats': 7.4,
#   'proteins': 7.0,
#   'carbohydrates': 48.3},
#  'Syrups, grenadine': {'calories': 268,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 66.91},
#  'Raisins, seedless': {'calories': 299,
#   'fats': 0.5,
#   'proteins': 3.07,
#   'carbohydrates': 79.18},
#  'Strawberries, raw': {'calories': 32,
#   'fats': 0.3,
#   'proteins': 0.67,
#   'carbohydrates': 7.68},
#  'Fish, raw, burbot': {'calories': 90,
#   'fats': 0.8,
#   'proteins': 19.31,
#   'carbohydrates': 0.0},
#  'Wheat germ, crude': {'calories': 360,
#   'fats': 9.7,
#   'proteins': 23.15,
#   'carbohydrates': 51.8},
#  'Wheat, hard white': {'calories': 342,
#   'fats': 1.7,
#   'proteins': 11.31,
#   'carbohydrates': 75.9},
#  'Wheat bran, crude': {'calories': 216,
#   'fats': 4.3,
#   'proteins': 15.55,
#   'carbohydrates': 64.51},
#  'Gooseberries, raw': {'calories': 44,
#   'fats': 0.6,
#   'proteins': 0.88,
#   'carbohydrates': 10.18},
#  'Spices, dill seed': {'calories': 305,
#   'fats': 15.0,
#   'proteins': 15.98,
#   'carbohydrates': 55.17},
#  'Oil, cocoa butter': {'calories': 884,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  "APPLEBEE'S, chili": {'calories': 157,
#   'fats': 9.8,
#   'proteins': 12.56,
#   'carbohydrates': 4.57},
#  'Grape leaves, raw': {'calories': 93,
#   'fats': 2.1,
#   'proteins': 5.6,
#   'carbohydrates': 17.31},
#  'Kale, raw, scotch': {'calories': 42,
#   'fats': 0.6,
#   'proteins': 2.8,
#   'carbohydrates': 8.32},
#  'Marmalade, orange': {'calories': 246,
#   'fats': 0.0,
#   'proteins': 0.3,
#   'carbohydrates': 66.3},
#  'Whey, dried, acid': {'calories': 339,
#   'fats': 0.5,
#   'proteins': 11.73,
#   'carbohydrates': 73.45},
#  'Whey, fluid, acid': {'calories': 24,
#   'fats': 0.1,
#   'proteins': 0.76,
#   'carbohydrates': 5.12},
#  'Eggplant, pickled': {'calories': 49,
#   'fats': 0.7,
#   'proteins': 0.9,
#   'carbohydrates': 9.77},
#  'Babyfood, cookies': {'calories': 433,
#   'fats': 13.0,
#   'proteins': 11.8,
#   'carbohydrates': 67.1},
#  'Fennel, raw, bulb': {'calories': 31,
#   'fats': 0.2,
#   'proteins': 1.24,
#   'carbohydrates': 7.3},
#  'Egg, dried, whole': {'calories': 592,
#   'fats': 44.0,
#   'proteins': 48.05,
#   'carbohydrates': 1.13},
#  'Coffeecake, fruit': {'calories': 311,
#   'fats': 10.0,
#   'proteins': 5.2,
#   'carbohydrates': 51.5},
#  'Candies, caramels': {'calories': 382,
#   'fats': 8.1,
#   'proteins': 4.6,
#   'carbohydrates': 77.0},
#  'Sour cream, light': {'calories': 136,
#   'fats': 11.0,
#   'proteins': 3.5,
#   'carbohydrates': 7.1},
#  'Egg, dried, white': {'calories': 382,
#   'fats': 0.0,
#   'proteins': 81.1,
#   'carbohydrates': 7.8},
#  'Wild rice, cooked': {'calories': 101,
#   'fats': 0.3,
#   'proteins': 3.99,
#   'carbohydrates': 21.34},
#  'Chicken, meatless': {'calories': 224,
#   'fats': 13.0,
#   'proteins': 23.64,
#   'carbohydrates': 3.64},
#  'Corn grain, white': {'calories': 365,
#   'fats': 4.7,
#   'proteins': 9.42,
#   'carbohydrates': 74.26},
#  'Veal, raw, ground': {'calories': 197,
#   'fats': 13.0,
#   'proteins': 18.58,
#   'carbohydrates': 0.0},
#  'Wheat, soft white': {'calories': 340,
#   'fats': 2.0,
#   'proteins': 10.69,
#   'carbohydrates': 75.36},
#  'Elderberries, raw': {'calories': 73,
#   'fats': 0.5,
#   'proteins': 0.66,
#   'carbohydrates': 18.4},
#  'Nuts, raw, acorns': {'calories': 387,
#   'fats': 24.0,
#   'proteins': 6.15,
#   'carbohydrates': 40.75},
#  'Orange juice, raw': {'calories': 45,
#   'fats': 0.2,
#   'proteins': 0.7,
#   'carbohydrates': 10.4},
#  'POPEYES, Coleslaw': {'calories': 161,
#   'fats': 11.0,
#   'proteins': 0.98,
#   'carbohydrates': 14.12},
#  'Cabbage, raw, red': {'calories': 31,
#   'fats': 0.2,
#   'proteins': 1.43,
#   'carbohydrates': 7.37},
#  'Blackberries, raw': {'calories': 43,
#   'fats': 0.5,
#   'proteins': 1.39,
#   'carbohydrates': 9.61},
#  'Wasabi, raw, root': {'calories': 109,
#   'fats': 0.6,
#   'proteins': 4.8,
#   'carbohydrates': 23.54},
#  'Cheese, limburger': {'calories': 327,
#   'fats': 27.0,
#   'proteins': 20.05,
#   'carbohydrates': 0.49},
#  'Raspberries, raw': {'calories': 52,
#   'fats': 0.7,
#   'proteins': 1.2,
#   'carbohydrates': 11.94},
#  'Corn bran, crude': {'calories': 224,
#   'fats': 0.9,
#   'proteins': 8.36,
#   'carbohydrates': 85.64},
#  'Bread, rice bran': {'calories': 243,
#   'fats': 4.6,
#   'proteins': 8.9,
#   'carbohydrates': 43.5},
#  'Taro shoots, raw': {'calories': 11,
#   'fats': 0.1,
#   'proteins': 0.92,
#   'carbohydrates': 2.32},
#  'Sugars, powdered': {'calories': 389,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 99.77},
#  'Emu, raw, ground': {'calories': 134,
#   'fats': 4.0,
#   'proteins': 22.77,
#   'carbohydrates': 0.0},
#  'Cookies, fortune': {'calories': 378,
#   'fats': 2.7,
#   'proteins': 4.2,
#   'carbohydrates': 84.0},
#  'Fish, raw, cisco': {'calories': 98,
#   'fats': 1.9,
#   'proteins': 18.99,
#   'carbohydrates': 0.0},
#  'Couscous, cooked': {'calories': 112,
#   'fats': 0.2,
#   'proteins': 3.79,
#   'carbohydrates': 23.22},
#  'Dill weed, fresh': {'calories': 43,
#   'fats': 1.1,
#   'proteins': 3.46,
#   'carbohydrates': 7.02},
#  'Spearmint, dried': {'calories': 285,
#   'fats': 6.0,
#   'proteins': 19.93,
#   'carbohydrates': 52.04},
#  'Spearmint, fresh': {'calories': 44,
#   'fats': 0.7,
#   'proteins': 3.29,
#   'carbohydrates': 8.41},
#  'Tamales (Navajo)': {'calories': 153,
#   'fats': 6.1,
#   'proteins': 6.28,
#   'carbohydrates': 18.12},
#  'Rice bran, crude': {'calories': 316,
#   'fats': 21.0,
#   'proteins': 13.35,
#   'carbohydrates': 49.69},
#  'Rye flour, light': {'calories': 357,
#   'fats': 1.3,
#   'proteins': 9.82,
#   'carbohydrates': 76.68},
#  'Spices, bay leaf': {'calories': 313,
#   'fats': 8.4,
#   'proteins': 7.61,
#   'carbohydrates': 74.97},
#  'Spices, cardamom': {'calories': 311,
#   'fats': 6.7,
#   'proteins': 10.76,
#   'carbohydrates': 68.47},
#  'Lemon juice, raw': {'calories': 22,
#   'fats': 0.2,
#   'proteins': 0.35,
#   'carbohydrates': 6.9},
#  'Ginger root, raw': {'calories': 80,
#   'fats': 0.8,
#   'proteins': 1.82,
#   'carbohydrates': 17.77},
#  'Fish oil, salmon': {'calories': 902,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Fish, tuna salad': {'calories': 187,
#   'fats': 9.3,
#   'proteins': 16.04,
#   'carbohydrates': 9.41},
#  'Orange peel, raw': {'calories': 97,
#   'fats': 0.2,
#   'proteins': 1.5,
#   'carbohydrates': 25.0},
#  'Blueberries, raw': {'calories': 57,
#   'fats': 0.3,
#   'proteins': 0.74,
#   'carbohydrates': 14.49},
#  'Cheese, muenster': {'calories': 368,
#   'fats': 30.0,
#   'proteins': 23.41,
#   'carbohydrates': 1.12},
#  'Beet greens, raw': {'calories': 22,
#   'fats': 0.1,
#   'proteins': 2.2,
#   'carbohydrates': 4.33},
#  'Cheese, cheshire': {'calories': 387,
#   'fats': 31.0,
#   'proteins': 23.37,
#   'carbohydrates': 4.78},
#  'Bagels, oat bran': {'calories': 255,
#   'fats': 1.2,
#   'proteins': 10.7,
#   'carbohydrates': 53.3},
#  'Fat, beef tallow': {'calories': 902,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Clementines, raw': {'calories': 47,
#   'fats': 0.2,
#   'proteins': 0.85,
#   'carbohydrates': 12.02},
#  'Peas, raw, green': {'calories': 81,
#   'fats': 0.4,
#   'proteins': 5.42,
#   'carbohydrates': 14.45},
#  'Oat bran, cooked': {'calories': 40,
#   'fats': 0.9,
#   'proteins': 3.21,
#   'carbohydrates': 11.44},
#  'Pears, bosc, raw': {'calories': 67,
#   'fats': 0.1,
#   'proteins': 0.36,
#   'carbohydrates': 16.1},
#  'Sugar, turbinado': {'calories': 399,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 99.8},
#  'Headcheese, pork': {'calories': 157,
#   'fats': 11.0,
#   'proteins': 13.83,
#   'carbohydrates': 0.0},
#  'Ham salad spread': {'calories': 216,
#   'fats': 16.0,
#   'proteins': 8.68,
#   'carbohydrates': 10.64},
#  'Olive loaf, pork': {'calories': 235,
#   'fats': 17.0,
#   'proteins': 11.8,
#   'carbohydrates': 9.2},
#  'Pastrami, turkey': {'calories': 139,
#   'fats': 6.2,
#   'proteins': 16.3,
#   'carbohydrates': 3.34},
#  'Cranberries, raw': {'calories': 46,
#   'fats': 0.1,
#   'proteins': 0.46,
#   'carbohydrates': 11.97},
#  'POPEYES, biscuit': {'calories': 401,
#   'fats': 24.0,
#   'proteins': 6.0,
#   'carbohydrates': 40.95},
#  'Egg, dried, yolk': {'calories': 669,
#   'fats': 59.0,
#   'proteins': 33.63,
#   'carbohydrates': 0.66},
#  'Quinoa, uncooked': {'calories': 368,
#   'fats': 6.1,
#   'proteins': 14.12,
#   'carbohydrates': 64.16},
#  'Emu, raw, oyster': {'calories': 141,
#   'fats': 4.9,
#   'proteins': 22.81,
#   'carbohydrates': 0.0},
#  'Rose-apples, raw': {'calories': 25,
#   'fats': 0.3,
#   'proteins': 0.6,
#   'carbohydrates': 5.7},
#  'Cheese, monterey': {'calories': 373,
#   'fats': 30.0,
#   'proteins': 24.48,
#   'carbohydrates': 0.68},
#  'Fish, raw, scup': {'calories': 105,
#   'fats': 2.7,
#   'proteins': 18.88,
#   'carbohydrates': 0.0},
#  'Cheese, cheddar': {'calories': 404,
#   'fats': 33.0,
#   'proteins': 22.87,
#   'carbohydrates': 3.09},
#  'Cheese, caraway': {'calories': 376,
#   'fats': 29.0,
#   'proteins': 25.18,
#   'carbohydrates': 3.06},
#  'Oil, wheat germ': {'calories': 884,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Bread, oat bran': {'calories': 236,
#   'fats': 4.4,
#   'proteins': 10.4,
#   'carbohydrates': 39.8},
#  'Watermelon, raw': {'calories': 30,
#   'fats': 0.2,
#   'proteins': 0.61,
#   'carbohydrates': 7.55},
#  'Potato pancakes': {'calories': 268,
#   'fats': 15.0,
#   'proteins': 6.08,
#   'carbohydrates': 27.81},
#  'Spinach souffle': {'calories': 172,
#   'fats': 13.0,
#   'proteins': 7.89,
#   'carbohydrates': 5.9},
#  'Bacon, meatless': {'calories': 309,
#   'fats': 30.0,
#   'proteins': 11.69,
#   'carbohydrates': 5.31},
#  'Rosemary, fresh': {'calories': 131,
#   'fats': 5.9,
#   'proteins': 3.31,
#   'carbohydrates': 20.7},
#  'Syrups, sorghum': {'calories': 290,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 74.9},
#  'Rye flour, dark': {'calories': 325,
#   'fats': 2.2,
#   'proteins': 15.91,
#   'carbohydrates': 68.63},
#  'Oil, tomatoseed': {'calories': 884,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Croutons, plain': {'calories': 407,
#   'fats': 6.6,
#   'proteins': 11.9,
#   'carbohydrates': 73.5},
#  'Lemon peel, raw': {'calories': 47,
#   'fats': 0.3,
#   'proteins': 1.5,
#   'carbohydrates': 16.0},
#  'Spices, paprika': {'calories': 282,
#   'fats': 13.0,
#   'proteins': 14.14,
#   'carbohydrates': 53.99},
#  'Nectarines, raw': {'calories': 44,
#   'fats': 0.3,
#   'proteins': 1.06,
#   'carbohydrates': 10.55},
#  'Mulberries, raw': {'calories': 43,
#   'fats': 0.4,
#   'proteins': 1.44,
#   'carbohydrates': 9.8},
#  'Lotus root, raw': {'calories': 74,
#   'fats': 0.1,
#   'proteins': 2.6,
#   'carbohydrates': 17.23},
#  'Sauce, barbecue': {'calories': 172,
#   'fats': 0.6,
# ...
#   'fats': 2.7,
#   'proteins': 3.05,
#   'carbohydrates': 21.15},
#  'Grapefruit juice, raw, white': {'calories': 39,
#   'fats': 0.1,
#   'proteins': 0.5,
#   'carbohydrates': 9.2},
#  'Babyfood, arrowroot, cookies': {'calories': 424,
#   'fats': 10.0,
#   'proteins': 7.6,
#   'carbohydrates': 75.4},
#  'Fish, raw, Atlantic, pollock': {'calories': 92,
#   'fats': 1.0,
#   'proteins': 19.44,
#   'carbohydrates': 0.0},
#  'Egg, raw, fresh, whole, duck': {'calories': 185,
#   'fats': 14.0,
#   'proteins': 12.81,
#   'carbohydrates': 1.45},
#  "McDONALD'S, Sausage McMUFFIN": {'calories': 333,
#   'fats': 21.0,
#   'proteins': 12.66,
#   'carbohydrates': 24.52},
#  'HEALTHY REQUEST Tomato juice': {'calories': 21,
#   'fats': 0.0,
#   'proteins': 0.82,
#   'carbohydrates': 4.53},
#  'Crackers, whole-wheat, matzo': {'calories': 351,
#   'fats': 1.5,
#   'proteins': 13.1,
#   'carbohydrates': 78.9},
#  'Soup, dry, cubed, beef broth': {'calories': 170,
#   'fats': 4.0,
#   'proteins': 17.3,
#   'carbohydrates': 16.1},
#  'Puddings, ready-to-eat, rice': {'calories': 108,
#   'fats': 2.2,
#   'proteins': 3.23,
#   'carbohydrates': 18.39},
#  'Pectin, dry mix, unsweetened': {'calories': 325,
#   'fats': 0.3,
#   'proteins': 0.3,
#   'carbohydrates': 90.4},
#  'Candies, CARAMELLO Candy Bar': {'calories': 462,
#   'fats': 21.0,
#   'proteins': 6.19,
#   'carbohydrates': 63.81},
#  'Veal, raw, external fat only': {'calories': 503,
#   'fats': 52.0,
#   'proteins': 8.85,
#   'carbohydrates': 0.89},
#  'Seeds, raw, breadfruit seeds': {'calories': 191,
#   'fats': 5.6,
#   'proteins': 7.4,
#   'carbohydrates': 29.24},
#  'Mushrooms, stir-fried, white': {'calories': 26,
#   'fats': 0.3,
#   'proteins': 3.58,
#   'carbohydrates': 4.04},
#  'Snacks, rolls, fruit leather': {'calories': 371,
#   'fats': 3.0,
#   'proteins': 0.1,
#   'carbohydrates': 85.8},
#  'Sauce, thin, white, homemade': {'calories': 105,
#   'fats': 6.7,
#   'proteins': 3.77,
#   'carbohydrates': 7.4},
#  'Sauce, ready-to-serve, salsa': {'calories': 29,
#   'fats': 0.2,
#   'proteins': 1.52,
#   'carbohydrates': 6.64},
#  'Peppers, raw, red, hot chili': {'calories': 40,
#   'fats': 0.4,
#   'proteins': 1.87,
#   'carbohydrates': 8.81},
#  'Squash, raw, scallop, summer': {'calories': 18,
#   'fats': 0.2,
#   'proteins': 1.2,
#   'carbohydrates': 3.84},
#  'Currants, raw, red and white': {'calories': 56,
#   'fats': 0.2,
#   'proteins': 1.4,
#   'carbohydrates': 13.8},
#  'Crustaceans, raw, blue, crab': {'calories': 87,
#   'fats': 1.1,
#   'proteins': 18.06,
#   'carbohydrates': 0.04},
#  'Pie fillings, cherry, canned': {'calories': 115,
#   'fats': 0.1,
#   'proteins': 0.37,
#   'carbohydrates': 28.0},
#  'Yogurt, nonfat, plain, Greek': {'calories': 59,
#   'fats': 0.4,
#   'proteins': 10.19,
#   'carbohydrates': 3.6},
#  'Crackers, reduced fat, wheat': {'calories': 444,
#   'fats': 13.0,
#   'proteins': 9.34,
#   'carbohydrates': 71.52},
#  'Gravy, powder, dry, mushroom': {'calories': 328,
#   'fats': 4.0,
#   'proteins': 10.0,
#   'carbohydrates': 64.66},
#  'Gravy, dry, unspecified type': {'calories': 344,
#   'fats': 8.0,
#   'proteins': 13.0,
#   'carbohydrates': 58.0},
#  'Seeds, low-fat, sesame flour': {'calories': 333,
#   'fats': 1.8,
#   'proteins': 50.14,
#   'carbohydrates': 35.51},
#  'Mushrooms, microwaved, white': {'calories': 35,
#   'fats': 0.5,
#   'proteins': 3.91,
#   'carbohydrates': 6.04},
#  'Beverages, AMP, Energy drink': {'calories': 46,
#   'fats': 0.1,
#   'proteins': 0.25,
#   'carbohydrates': 12.08},
#  'SILK Black Cherry soy yogurt': {'calories': 88,
#   'fats': 1.2,
#   'proteins': 2.35,
#   'carbohydrates': 17.06},
#  'Snack, original bar, BALANCE': {'calories': 415,
#   'fats': 12.0,
#   'proteins': 28.0,
#   'carbohydrates': 48.73},
#  'Beverages, well, tap, water': {'calories': 0,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Chrysanthemum, raw, garland': {'calories': 24,
#   'fats': 0.6,
#   'proteins': 3.36,
#   'carbohydrates': 3.02},
#  'Stew, moose (Alaska Native)': {'calories': 55,
#   'fats': 0.5,
#   'proteins': 6.6,
#   'carbohydrates': 6.0},
#  'Ice creams, rich, chocolate': {'calories': 251,
#   'fats': 17.0,
#   'proteins': 4.72,
#   'carbohydrates': 19.78},
#  'Oil, walrus (Alaska Native)': {'calories': 900,
#   'fats': 100.0,
#   'proteins': 0.0,
#   'carbohydrates': 0.0},
#  'Grapefruit juice, raw, pink': {'calories': 39,
#   'fats': 0.1,
#   'proteins': 0.5,
#   'carbohydrates': 9.2},
#  'Babyfood, junior, ham, meat': {'calories': 97,
#   'fats': 3.8,
#   'proteins': 11.3,
#   'carbohydrates': 3.7},
#  'Radish seeds, raw, sprouted': {'calories': 43,
#   'fats': 2.5,
#   'proteins': 3.81,
#   'carbohydrates': 3.6},
#  'MORI-NU, firm, silken, Tofu': {'calories': 62,
#   'fats': 2.7,
#   'proteins': 6.9,
#   'carbohydrates': 2.4},
#  'MORI-NU, soft, silken, Tofu': {'calories': 55,
#   'fats': 2.7,
#   'proteins': 4.8,
#   'carbohydrates': 2.9},
#  'Bread, rye, reduced-calorie': {'calories': 203,
#   'fats': 2.9,
#   'proteins': 9.1,
#   'carbohydrates': 40.5},
#  'Snacks, air-popped, popcorn': {'calories': 387,
#   'fats': 4.5,
#   'proteins': 12.94,
#   'carbohydrates': 77.78},
#  'Muffins, dry mix, blueberry': {'calories': 293,
#   'fats': 3.3,
#   'proteins': 3.48,
#   'carbohydrates': 61.0},
#  'Frankfurter, unheated, beef': {'calories': 316,
#   'fats': 28.0,
#   'proteins': 11.16,
#   'carbohydrates': 3.36},
#  'Turkey, raw, giblets, whole': {'calories': 124,
#   'fats': 5.1,
#   'proteins': 18.18,
#   'carbohydrates': 0.07},
#  'Corn pudding, home prepared': {'calories': 131,
#   'fats': 5.0,
#   'proteins': 4.42,
#   'carbohydrates': 16.97},
#  'Popovers, enriched, dry mix': {'calories': 371,
#   'fats': 4.3,
#   'proteins': 10.4,
#   'carbohydrates': 71.0},
#  'Soybeans, raw, mature seeds': {'calories': 446,
#   'fats': 20.0,
#   'proteins': 36.49,
#   'carbohydrates': 30.16},
#  'Beef sausage, cooked, fresh': {'calories': 332,
#   'fats': 28.0,
#   'proteins': 18.21,
#   'carbohydrates': 0.35},
#  'Luncheon meat, canned, pork': {'calories': 334,
#   'fats': 30.0,
#   'proteins': 12.5,
#   'carbohydrates': 2.1},
#  'MURRAY, Vanilla Sugar Wafer': {'calories': 527,
#   'fats': 26.0,
#   'proteins': 3.9,
#   'carbohydrates': 70.0},
#  'Radishes, raw, white icicle': {'calories': 14,
#   'fats': 0.1,
#   'proteins': 1.1,
#   'carbohydrates': 2.63},
#  'Vinespinach, raw, (basella)': {'calories': 19,
#   'fats': 0.3,
#   'proteins': 1.8,
#   'carbohydrates': 3.4},
#  'Syrups, high-fructose, corn': {'calories': 281,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 76.0},
#  'Stew, steamed corn (Navajo)': {'calories': 112,
#   'fats': 3.8,
#   'proteins': 8.82,
#   'carbohydrates': 10.8},
#  'OSCAR MAYER, Bologna (beef)': {'calories': 316,
#   'fats': 29.0,
#   'proteins': 11.05,
#   'carbohydrates': 2.45},
#  'Ostrich, raw, outside strip': {'calories': 120,
#   'fats': 2.2,
#   'proteins': 23.36,
#   'carbohydrates': 0.0},
#  'Milk, fluid, indian buffalo': {'calories': 97,
#   'fats': 6.9,
#   'proteins': 3.75,
#   'carbohydrates': 5.18},
#  'Nuts, dried, black, walnuts': {'calories': 619,
#   'fats': 59.0,
#   'proteins': 24.06,
#   'carbohydrates': 9.58},
#  'ON THE BORDER, Mexican rice': {'calories': 195,
#   'fats': 4.9,
#   'proteins': 3.56,
#   'carbohydrates': 34.15},
#  'Mushrooms, raw, Chanterelle': {'calories': 38,
#   'fats': 0.5,
#   'proteins': 1.49,
#   'carbohydrates': 6.86},
#  "McDONALD'S, Baked Apple Pie": {'calories': 323,
#   'fats': 16.0,
#   'proteins': 3.07,
#   'carbohydrates': 43.62},
#  "McDONALD'S, Sausage Biscuit": {'calories': 376,
#   'fats': 25.0,
#   'proteins': 9.62,
#   'carbohydrates': 27.2},
#  'CHICK-FIL-A, Chick-n-Strips': {'calories': 228,
#   'fats': 11.0,
#   'proteins': 21.4,
#   'carbohydrates': 10.39},
#  'Edamame, unprepared, frozen': {'calories': 109,
#   'fats': 4.7,
#   'proteins': 11.22,
#   'carbohydrates': 7.61},
#  'Mollusks, raw, blue, mussel': {'calories': 86,
#   'fats': 2.2,
#   'proteins': 11.9,
#   'carbohydrates': 3.69},
#  'Quail, total edible, cooked': {'calories': 227,
#   'fats': 14.0,
#   'proteins': 25.1,
#   'carbohydrates': 0.0},
#  'Cereals, dry, CREAM OF RICE': {'calories': 370,
#   'fats': 0.5,
#   'proteins': 6.3,
#   'carbohydrates': 82.4},
#  'LEAN POCKETS, Ham N Cheddar': {'calories': 230,
#   'fats': 6.5,
#   'proteins': 10.28,
#   'carbohydrates': 32.52},
#  'Snacks, tropical, trail mix': {'calories': 442,
#   'fats': 17.0,
#   'proteins': 6.3,
#   'carbohydrates': 65.6},
#  'Nuts, full fat, acorn flour': {'calories': 501,
#   'fats': 30.0,
#   'proteins': 7.49,
#   'carbohydrates': 54.65},
#  'Sauce, ready-to-serve, fish': {'calories': 35,
#   'fats': 0.0,
#   'proteins': 5.06,
#   'carbohydrates': 3.64},
#  'Fish, raw, european, turbot': {'calories': 95,
#   'fats': 3.0,
#   'proteins': 16.05,
#   'carbohydrates': 0.0},
#  'Fast foods, caramel, sundae': {'calories': 196,
#   'fats': 6.0,
#   'proteins': 4.71,
#   'carbohydrates': 31.81},
#  'Pie fillings, canned, apple': {'calories': 100,
#   'fats': 0.1,
#   'proteins': 0.1,
#   'carbohydrates': 26.1},
#  'Sauce, ready-to-serve, plum': {'calories': 184,
#   'fats': 1.0,
#   'proteins': 0.89,
#   'carbohydrates': 42.81},
#  'Ostrich, cooked, inside leg': {'calories': 141,
#   'fats': 1.9,
#   'proteins': 29.01,
#   'carbohydrates': 0.0},
#  "Gravy, mushroom, CAMPBELL'S": {'calories': 34,
#   'fats': 1.7,
#   'proteins': 0.0,
#   'carbohydrates': 5.08},
#  'Snacks, smoked, beef sticks': {'calories': 550,
#   'fats': 50.0,
#   'proteins': 21.5,
#   'carbohydrates': 5.4},
#  'Cheese, whole milk, ricotta': {'calories': 174,
#   'fats': 13.0,
#   'proteins': 11.26,
#   'carbohydrates': 3.04},
#  'SILK French Vanilla Creamer': {'calories': 133,
#   'fats': 6.7,
#   'proteins': 0.0,
#   'carbohydrates': 20.0},
#  'Bread, canned, boston brown': {'calories': 195,
#   'fats': 1.5,
#   'proteins': 5.2,
#   'carbohydrates': 43.3},
#  'Cheese, queso blanco, white': {'calories': 310,
#   'fats': 24.0,
#   'proteins': 20.38,
#   'carbohydrates': 2.53},
#  'Cheese, queso fresco, fresh': {'calories': 299,
#   'fats': 24.0,
#   'proteins': 18.09,
#   'carbohydrates': 2.98},
#  'Beverages, powder, Lemonade': {'calories': 376,
#   'fats': 1.1,
#   'proteins': 0.0,
#   'carbohydrates': 97.57},
#  'Apricots, sweetened, frozen': {'calories': 98,
#   'fats': 0.1,
#   'proteins': 0.7,
#   'carbohydrates': 25.1},
#  'Muffins, toaster-type, corn': {'calories': 346,
#   'fats': 11.0,
#   'proteins': 5.3,
#   'carbohydrates': 57.9},
#  'Tomatoes, cooked, ripe, red': {'calories': 18,
#   'fats': 0.1,
#   'proteins': 0.95,
#   'carbohydrates': 4.01},
#  'Squash, raw, baby, zucchini': {'calories': 21,
#   'fats': 0.4,
#   'proteins': 2.71,
#   'carbohydrates': 3.11},
#  'HORMEL Canadian Style Bacon': {'calories': 122,
#   'fats': 4.9,
#   'proteins': 16.88,
#   'carbohydrates': 1.87},
#  "McDONALD'S, QUARTER POUNDER": {'calories': 244,
#   'fats': 12.0,
#   'proteins': 14.1,
#   'carbohydrates': 22.17},
#  'Brotwurst, link, beef, pork': {'calories': 323,
#   'fats': 28.0,
#   'proteins': 14.3,
#   'carbohydrates': 2.98},
#  'Pork, cooked, ground, fresh': {'calories': 297,
#   'fats': 21.0,
#   'proteins': 25.69,
#   'carbohydrates': 0.0},
#  'Sausage, raw, pork, Italian': {'calories': 346,
#   'fats': 31.0,
#   'proteins': 14.25,
#   'carbohydrates': 0.65},
#  'Ham and cheese loaf or roll': {'calories': 241,
#   'fats': 19.0,
#   'proteins': 13.6,
#   'carbohydrates': 4.0},
#  'CRACKER BARREL, steak fries': {'calories': 255,
#   'fats': 13.0,
#   'proteins': 3.26,
#   'carbohydrates': 30.87},
#  "McDONALD'S, Sausage Burrito": {'calories': 277,
#   'fats': 16.0,
#   'proteins': 11.1,
#   'carbohydrates': 22.97},
#  'Candies, CHUNKY Bar, NESTLE': {'calories': 475,
#   'fats': 28.0,
#   'proteins': 7.5,
#   'carbohydrates': 60.0},
#  'Fish, raw, freshwater, drum': {'calories': 119,
#   'fats': 4.9,
#   'proteins': 17.54,
#   'carbohydrates': 0.0},
#  'Pate, canned, chicken liver': {'calories': 201,
#   'fats': 13.0,
#   'proteins': 13.45,
#   'carbohydrates': 6.55},
#  'BURGER KING, Chicken Strips': {'calories': 292,
#   'fats': 15.0,
#   'proteins': 18.2,
#   'carbohydrates': 20.49},
#  'Pork, raw, salt pork, cured': {'calories': 748,
#   'fats': 81.0,
#   'proteins': 5.05,
#   'carbohydrates': 0.0},
#  'Cereals ready-to-eat, ALPEN': {'calories': 352,
#   'fats': 3.3,
#   'proteins': 11.2,
#   'carbohydrates': 75.7},
#  'Light ice cream, Creamsicle': {'calories': 165,
#   'fats': 3.1,
#   'proteins': 1.54,
#   'carbohydrates': 32.75},
#  'Toppings, marshmallow cream': {'calories': 322,
#   'fats': 0.3,
#   'proteins': 0.8,
#   'carbohydrates': 79.0},
#  'Fish, raw, Pacific, herring': {'calories': 195,
#   'fats': 14.0,
#   'proteins': 16.39,
#   'carbohydrates': 0.0},
#  'Sandwich spread, beef, pork': {'calories': 235,
#   'fats': 17.0,
#   'proteins': 7.66,
#   'carbohydrates': 11.94},
#  'Nuts, hazelnuts or filberts': {'calories': 628,
#   'fats': 61.0,
#   'proteins': 14.95,
#   'carbohydrates': 16.7},
#  'Babyfood, teething biscuits': {'calories': 392,
#   'fats': 4.2,
#   'proteins': 10.7,
#   'carbohydrates': 76.4},
#  'PACE, Organic Picante Sauce': {'calories': 25,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 6.25},
#  'Peppers, raw, yellow, sweet': {'calories': 27,
#   'fats': 0.2,
#   'proteins': 1.0,
#   'carbohydrates': 6.32},
#  'Fish, raw, florida, pompano': {'calories': 164,
#   'fats': 9.5,
#   'proteins': 18.48,
#   'carbohydrates': 0.0},
#  'Potato salad, home-prepared': {'calories': 143,
#   'fats': 8.2,
#   'proteins': 2.68,
#   'carbohydrates': 11.17},
#  'GIRL SCOUTS, Chalet Cookies': {'calories': 478,
#   'fats': 19.0,
#   'proteins': 4.2,
#   'carbohydrates': 72.3},
#  'GIRL SCOUTS, Samoas Cookies': {'calories': 489,
#   'fats': 26.0,
#   'proteins': 3.5,
#   'carbohydrates': 64.1},
#  'Cheese, semisoft type, goat': {'calories': 364,
#   'fats': 30.0,
#   'proteins': 21.58,
#   'carbohydrates': 0.12},
#  'Game meat, raw, ground, elk': {'calories': 172,
#   'fats': 8.8,
#   'proteins': 21.76,
#   'carbohydrates': 0.0},
#  'Candies, unsweetened, carob': {'calories': 540,
#   'fats': 31.0,
#   'proteins': 8.15,
#   'carbohydrates': 56.29},
#  'Babyfood, toddler, potatoes': {'calories': 52,
#   'fats': 0.1,
#   'proteins': 1.0,
#   'carbohydrates': 11.73},
#  'Veal, cooked, seam fat only': {'calories': 505,
#   'fats': 50.0,
#   'proteins': 11.16,
#   'carbohydrates': 2.11},
#  'Sauce, ready-to-serve, duck': {'calories': 245,
#   'fats': 0.1,
#   'proteins': 0.36,
#   'carbohydrates': 60.61},
#  'Corn dogs, prepared, frozen': {'calories': 250,
#   'fats': 12.0,
#   'proteins': 8.57,
#   'carbohydrates': 26.96},
#  'Seeds, paste, sesame butter': {'calories': 586,
#   'fats': 51.0,
#   'proteins': 18.08,
#   'carbohydrates': 24.05},
#  'Noodles, enriched, dry, egg': {'calories': 384,
#   'fats': 4.4,
#   'proteins': 14.16,
#   'carbohydrates': 71.27},
#  'Persimmons, dried, japanese': {'calories': 274,
#   'fats': 0.6,
#   'proteins': 1.38,
#   'carbohydrates': 73.43},
#  'Carrots, unprepared, frozen': {'calories': 36,
#   'fats': 0.5,
#   'proteins': 0.78,
#   'carbohydrates': 7.9},
#  'Carambola, raw, (starfruit)': {'calories': 31,
#   'fats': 0.3,
#   'proteins': 1.04,
#   'carbohydrates': 6.73},
#  'Fast foods, chicken tenders': {'calories': 271,
#   'fats': 14.0,
#   'proteins': 19.22,
#   'carbohydrates': 17.25},
#  'Beans, home prepared, baked': {'calories': 155,
#   'fats': 5.2,
#   'proteins': 5.54,
#   'carbohydrates': 21.63},
#  'Cream, half and half, fluid': {'calories': 123,
#   'fats': 10.0,
#   'proteins': 3.13,
#   'carbohydrates': 4.73},
#  'SILK Light Vanilla, soymilk': {'calories': 33,
#   'fats': 0.8,
#   'proteins': 2.47,
#   'carbohydrates': 4.12},
#  'Turnips, unprepared, frozen': {'calories': 16,
#   'fats': 0.2,
#   'proteins': 1.04,
#   'carbohydrates': 2.94},
#  'PACE, Cilantro Chunky Salsa': {'calories': 25,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 6.25},
#  'PACE, Chipotle Chunky Salsa': {'calories': 25,
#   'fats': 0.0,
#   'proteins': 0.0,
#   'carbohydrates': 6.25},
#  'Jams and preserves, apricot': {'calories': 242,
#   'fats': 0.2,
#   'proteins': 0.7,
#   'carbohydrates': 64.4},
#  'Butter, with salt, whipped': {'calories': 718,
#   'fats': 78.0,
#   'proteins': 0.49,
#   'carbohydrates': 2.87},
#  'Ham, cooked, smoked, honey': {'calories': 122,
#   'fats': 2.4,
#   'proteins': 17.93,
#   'carbohydrates': 7.27},
#  'Spaghetti, cooked, spinach': {'calories': 130,
#   'fats': 0.6,
#   'proteins': 4.58,
#   'carbohydrates': 26.15},
#  'Bockwurst, raw, veal, pork': {'calories': 301,
#   'fats': 26.0,
#   'proteins': 14.03,
#   'carbohydrates': 2.95},
#  'Guinea hen, raw, meat only': {'calories': 110,
#   'fats': 2.5,
#   'proteins': 20.64,
#   'carbohydrates': 0.0},
#  'Cookies, soft-type, raisin': {'calories': 401,
#   'fats': 14.0,
#   'proteins': 4.1,
#   'carbohydrates': 68.0},
#  'Squash, raw, acorn, winter': {'calories': 40,
#   'fats': 0.1,
#   'proteins': 0.8,
#   'carbohydrates': 10.42},
#  ...}
